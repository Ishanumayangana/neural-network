# %%
# import methods to convert images to numerical array and load images
from tensorflow.keras.utils import img_to_array, load_img

# %%
# load image
img = load_img('elephant.jpg')

# %%
img.show()

# %%
# convert image to numerical array
x = img_to_array(img)

# %%
# reshape image
x = x.reshape((1,) + x.shape)

# %%
x.shape
# Out:
# (1, 1, 600, 1000, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# initialize data augmentation object
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
# apply data augmentation on images
i = 0
for batch in datagen.flow(x, batch_size=1, save_to_dir='augmented_images', save_prefix='elephant', save_format='jpeg'):
    i += 1
    if i > 20:
        break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8ba4cfca1c21> in <cell line: 3>()
#       1 # apply data augmentation on images
#       2 i = 0
# ----> 3 for batch in datagen.flow(x, batch_size=1, save_to_dir='augmented_images', save_prefix='elephant', save_format='jpeg'):
#       4     i += 1
#       5     if i > 20:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in flow(self, x, y, batch_size, shuffle, sample_weight, seed, save_to_dir, save_prefix, save_format, ignore_class_split, subset)
#    1543
#    1544         """
# -> 1545         return NumpyArrayIterator(
#    1546             x,
#    1547             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in __init__(self, x, y, image_data_generator, batch_size, shuffle, sample_weight, seed, data_format, save_to_dir, save_prefix, save_format, subset, ignore_class_split, dtype)
#     756         self.x_misc = x_misc
#     757         if self.x.ndim != 4:
# --> 758             raise ValueError(
#     759                 "Input data in `NumpyArrayIterator` "
#     760                 "should have rank 4. You passed an array "
#
# ValueError: ('Input data in `NumpyArrayIterator` should have rank 4. You passed an array with shape', (1, 1, 600, 1000, 3))

# %%
from google.colab import drive
drive.mount('/content/drive')
